# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepdebug233/PCA/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
import seaborn as sn

# %%
sn.histplot(df.Cholesterol,kde = True)
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Count'>

# %%
sn.histplot(df.RestingBP,kde = True)
# Out:
# <Axes: xlabel='RestingBP', ylabel='Count'>

# %%
sn.histplot(df.FastingBS,kde = True)
# Out:
# <Axes: xlabel='FastingBS', ylabel='Count'>

# %%
sn.histplot(df.MaxHR,kde = True)
# Out:
# <Axes: xlabel='MaxHR', ylabel='Count'>

# %%
df.RestingBP.mean()-3*df.RestingBP.std()
# Out:
# 76.85405180149661

# %%
df.RestingBP.mean()+3*df.RestingBP.std()
# Out:
# 187.93897652094347

# %%
z_RestingBP<3
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 913    True
# 914    True
# 915    True
# 916    True
# 917    True
# Name: RestingBP, Length: 918, dtype: bool

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
z_RestingBP = (df.RestingBP-df.RestingBP.mean())/df.RestingBP.std()
z_RestingBP
# Out:
# 0      0.410685
# 1      1.490940
# 2     -0.129442
# 3      0.302660
# 4      0.950812
#          ...
# 913   -1.209697
# 914    0.626736
# 915   -0.129442
# 916   -0.129442
# 917    0.302660
# Name: RestingBP, Length: 918, dtype: float64

# %%
df[df.Cholesterol>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 909   63   F           ASY        124          197          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...
